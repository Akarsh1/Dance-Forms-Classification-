# %% [markdown]
# # Source Code

# %%
# Seeding ramdom functions
from numpy.random import seed
seed(1)
import tensorflow
tensorflow.random.set_seed(2)

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os.path
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from keras.applications import ResNet50
from keras.optimizers import Adam
import cv2
from tqdm import tqdm
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras import applications
from keras.applications import Xception
from keras.models import Model
from keras import optimizers
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from kerastuner import HyperModel
from kerastuner.tuners import RandomSearch

# %%
# Loading Training and testing data
#train_csv=pd.read_csv("/content/drive/My Drive/Deep Learning Projects/dataset/train.csv")
train_csv=pd.read_csv("/content/drive/My Drive/Deep Learning Projects/dataset/train_modified.csv")
test_csv=pd.read_csv("/content/drive/My Drive/Deep Learning Projects/dataset/test.csv")

# %%
train_csv.head()
# Out:
#      Image         target
# 0   96.jpg       manipuri
# 1  163.jpg  bharatanatyam
# 2  450.jpg         odissi
# 3  219.jpg      kathakali
# 4  455.jpg         odissi

# %%
#Printing number of instances in Training and testing data
# Originally, there were 364 examples but due to class-imbalance, we have added reqd images with the other training images.
print("Total number of instances in training data is : {} ".format(train_csv.shape[0]))
print("Total number of instances in testing data is : {} ".format(test_csv.shape[0]))
# Out:
# Total number of instances in training data is : 378
# Total number of instances in testing data is : 156

# %%
#Determining unique data categories in target label
# Earlier, Manipuri had 36 samples which accounted for class-imbalanceness.
train_csv['target'].value_counts()
# Out:
# manipuri         50
# mohiniyattam     50
# odissi           49
# kathakali        47
# bharatanatyam    47
# kuchipudi        46
# sattriya         45
# kathak           44
# Name: target, dtype: int64

# %%
# Visualizing samples in different categories in training data
labels_count = train_csv['target'].value_counts()
plt.figure(figsize=(18,10))
sns.barplot(labels_count.index,labels_count.values)
plt.xticks(rotation='horizontal')
plt.xlabel('Image Class',fontsize=12)
plt.ylabel('Counts',fontsize=12)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Images in training and testing data
TRAIN_PATH = "/content/drive/My Drive/Deep Learning Projects/dataset/train/"
TEST_PATH = "/content/drive/My Drive/Deep Learning Projects/dataset/test/"

# %%
# Reading image
IMAGE_SIZE = 224
def read_img(img_path):
  img = cv2.imread(img_path,cv2.IMREAD_COLOR)
  img = cv2.resize(img,(IMAGE_SIZE,IMAGE_SIZE))
  return img

# %%
# Calling the read_img function
train_img = []
for img_name in tqdm(train_csv['Image'].values):
  train_img.append(read_img(TRAIN_PATH+img_name))
# Out:
# 100%|██████████| 378/378 [03:36<00:00,  1.74it/s]

# %%
# Converting it into float arrays and normalizing it
X = np.array(train_img,np.float32)/255
print(X.shape)
# Out:
# (378, 224, 224, 3)

# %%
#Calculating the mean of the image
mean_img = np.mean(X,axis=0)
plt.imshow(mean_img)

# %%
# Caculating the std 
std_img = np.std(X,axis=0)
plt.imshow(std_img)

# %%
# Normalizing the image data X
X = (X-mean_img) / std_img
X.shape
# Out:
# (378, 224, 224, 3)

# %%
# Assigning output labels unique numbers
label_list = train_csv["target"].tolist()
label_numeric = {k:v for v,k in enumerate(set(label_list))}
y = [label_numeric[k] for k in label_list]
y = np.array(y)

# %%
# Encoding y outputs
y = to_categorical(y,num_classes=8)

# %%
print(y.shape)
# Out:
# (378, 8)

# %%
# Splitting the data into train and validation set
from sklearn.model_selection import train_test_split
x_train,x_valid,y_train,y_valid = train_test_split(X,y,test_size=0.2,random_state=1,stratify=y)

# %%
# Defining base model
base_model = applications.Xception(include_top=False,weights='imagenet',input_shape=(IMAGE_SIZE,IMAGE_SIZE,3))

# %%
add_model = Sequential()
add_model.add(Flatten(input_shape=base_model.output_shape[1:]))
add_model.add(Dropout(0.5))
add_model.add(Dense(512,activation='relu'))
add_model.add(Dropout(0.5))
add_model.add(Dense(y.shape[1],activation='softmax'))
model = Model(inputs=base_model.input,outputs = add_model(base_model.output))
model.compile(loss='categorical_crossentropy', optimizer=optimizers.Adam(lr=1e-5), metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 111, 111, 32) 864         input_7[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 111, 111, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 111, 111, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 109, 109, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 109, 109, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 109, 109, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 109, 109, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 109, 109, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 109, 109, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 109, 109, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 109, 109, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 55, 55, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 55, 55, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 55, 55, 128)  512         conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, 55, 55, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 55, 55, 128)  0           add_72[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 55, 55, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 55, 55, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 55, 55, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 55, 55, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 55, 55, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 256)  32768       add_72[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 28, 28, 256)  1024        conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 28, 28, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 28, 28, 256)  0           add_73[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 28, 28, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 28, 28, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 28, 28, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 28, 28, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 28, 28, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 728)  186368      add_73[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 14, 14, 728)  2912        conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 14, 14, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 14, 14, 728)  0           add_74[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 14, 14, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 14, 14, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 14, 14, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 14, 14, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 14, 14, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 14, 14, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 14, 14, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 14, 14, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 14, 14, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_74[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 14, 14, 728)  0           add_75[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 14, 14, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 14, 14, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 14, 14, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 14, 14, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 14, 14, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 14, 14, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 14, 14, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 14, 14, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 14, 14, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_75[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 14, 14, 728)  0           add_76[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 14, 14, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 14, 14, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 14, 14, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 14, 14, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 14, 14, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 14, 14, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 14, 14, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 14, 14, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 14, 14, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_76[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 14, 14, 728)  0           add_77[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 14, 14, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 14, 14, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 14, 14, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 14, 14, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 14, 14, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 14, 14, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 14, 14, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 14, 14, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 14, 14, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_77[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 14, 14, 728)  0           add_78[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 14, 14, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 14, 14, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 14, 14, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 14, 14, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 14, 14, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 14, 14, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 14, 14, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 14, 14, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 14, 14, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_78[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 14, 14, 728)  0           add_79[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 14, 14, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 14, 14, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 14, 14, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 14, 14, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 14, 14, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 14, 14, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 14, 14, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 14, 14, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 14, 14, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_79[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 14, 14, 728)  0           add_80[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 14, 14, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 14, 14, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 14, 14, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 14, 14, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 14, 14, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 14, 14, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 14, 14, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 14, 14, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 14, 14, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_80[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 14, 14, 728)  0           add_81[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 14, 14, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 14, 14, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 14, 14, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 14, 14, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 14, 14, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 14, 14, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 14, 14, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 14, 14, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 14, 14, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_81[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 14, 14, 728)  0           add_82[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 14, 14, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 14, 14, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 14, 14, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 14, 14, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 14, 14, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 7, 7, 1024)   745472      add_82[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 7, 7, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 7, 7, 1024)   4096        conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 7, 7, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 7, 7, 1536)   1582080     add_83[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 7, 7, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 7, 7, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 7, 7, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 7, 7, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 7, 7, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# sequential_6 (Sequential)       (None, 8)            51384840    block14_sepconv2_act[0][0]
# ==================================================================================================
# Total params: 72,246,320
# Trainable params: 72,191,792
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
# Data Augumentation
train_datagen = ImageDataGenerator(
        rotation_range=30, 
        width_shift_range=0.1, 
        height_shift_range=0.1,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
train_datagen.fit(x_train)

# %%
# Training of Model
batch_size = 4
epochs=60
history = model.fit(train_datagen.flow(x_train,y_train,batch_size=batch_size),validation_data=(x_valid,y_valid),steps_per_epoch=len(x_train)//batch_size,epochs=epochs)
# Out:
# Epoch 1/60
# 75/75 [==============================] - 14s 122ms/step - loss: 2.4091 - accuracy: 0.1349 - val_loss: 2.1936 - val_accuracy: 0.2368
# Epoch 2/60
# 75/75 [==============================] - 9s 114ms/step - loss: 2.1240 - accuracy: 0.1964 - val_loss: 1.8780 - val_accuracy: 0.3684
# Epoch 3/60
# 75/75 [==============================] - 9s 114ms/step - loss: 1.9675 - accuracy: 0.2869 - val_loss: 1.7441 - val_accuracy: 0.4079
# Epoch 4/60
# 75/75 [==============================] - 9s 115ms/step - loss: 1.8774 - accuracy: 0.2806 - val_loss: 1.6069 - val_accuracy: 0.4342
# Epoch 5/60
# 75/75 [==============================] - 9s 115ms/step - loss: 1.8059 - accuracy: 0.3732 - val_loss: 1.5591 - val_accuracy: 0.4868
# Epoch 6/60
# 75/75 [==============================] - 9s 115ms/step - loss: 1.6611 - accuracy: 0.3943 - val_loss: 1.4511 - val_accuracy: 0.5395
# Epoch 7/60
# 75/75 [==============================] - 9s 115ms/step - loss: 1.5122 - accuracy: 0.4821 - val_loss: 1.3906 - val_accuracy: 0.4737
# Epoch 8/60
# 75/75 [==============================] - 9s 114ms/step - loss: 1.3216 - accuracy: 0.5498 - val_loss: 1.2519 - val_accuracy: 0.5395
# Epoch 9/60
# 75/75 [==============================] - 8s 113ms/step - loss: 1.1890 - accuracy: 0.5778 - val_loss: 1.2021 - val_accuracy: 0.5526
# Epoch 10/60
# 75/75 [==============================] - 9s 113ms/step - loss: 1.2712 - accuracy: 0.5770 - val_loss: 1.1446 - val_accuracy: 0.5789
# Epoch 11/60
# 75/75 [==============================] - 9s 114ms/step - loss: 1.0859 - accuracy: 0.6638 - val_loss: 1.0656 - val_accuracy: 0.6579
# Epoch 12/60
# 75/75 [==============================] - 9s 114ms/step - loss: 1.0030 - accuracy: 0.6288 - val_loss: 1.0523 - val_accuracy: 0.6316
# Epoch 13/60
# 75/75 [==============================] - 9s 114ms/step - loss: 1.0022 - accuracy: 0.6336 - val_loss: 1.0652 - val_accuracy: 0.6842
# Epoch 14/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.9287 - accuracy: 0.6516 - val_loss: 1.0100 - val_accuracy: 0.6711
# Epoch 15/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.9264 - accuracy: 0.7087 - val_loss: 1.0170 - val_accuracy: 0.6579
# Epoch 16/60
# 75/75 [==============================] - 9s 113ms/step - loss: 0.8276 - accuracy: 0.6914 - val_loss: 0.9658 - val_accuracy: 0.7105
# Epoch 17/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.6984 - accuracy: 0.7509 - val_loss: 1.1301 - val_accuracy: 0.6579
# Epoch 18/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.6634 - accuracy: 0.7773 - val_loss: 0.9606 - val_accuracy: 0.7237
# Epoch 19/60
# 75/75 [==============================] - 9s 113ms/step - loss: 0.6043 - accuracy: 0.7904 - val_loss: 0.9486 - val_accuracy: 0.7105
# Epoch 20/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.6718 - accuracy: 0.7876 - val_loss: 0.9817 - val_accuracy: 0.6974
# Epoch 21/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.5715 - accuracy: 0.7987 - val_loss: 0.9740 - val_accuracy: 0.6974
# Epoch 22/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.6022 - accuracy: 0.7870 - val_loss: 1.0923 - val_accuracy: 0.7237
# Epoch 23/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.5534 - accuracy: 0.8085 - val_loss: 0.9896 - val_accuracy: 0.7237
# Epoch 24/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.4546 - accuracy: 0.8457 - val_loss: 0.9752 - val_accuracy: 0.7105
# Epoch 25/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.4181 - accuracy: 0.8691 - val_loss: 0.9605 - val_accuracy: 0.7237
# Epoch 26/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.4137 - accuracy: 0.8526 - val_loss: 0.9465 - val_accuracy: 0.7632
# Epoch 27/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.3780 - accuracy: 0.8868 - val_loss: 0.9637 - val_accuracy: 0.7632
# Epoch 28/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.3998 - accuracy: 0.8915 - val_loss: 0.9699 - val_accuracy: 0.7500
# Epoch 29/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.3777 - accuracy: 0.8849 - val_loss: 0.9532 - val_accuracy: 0.7368
# Epoch 30/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.6080 - accuracy: 0.8047 - val_loss: 0.9307 - val_accuracy: 0.7632
# Epoch 31/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.2682 - accuracy: 0.9125 - val_loss: 0.8721 - val_accuracy: 0.7895
# Epoch 32/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.3960 - accuracy: 0.8747 - val_loss: 0.9021 - val_accuracy: 0.7895
# Epoch 33/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.2915 - accuracy: 0.9035 - val_loss: 0.8797 - val_accuracy: 0.7763
# Epoch 34/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.2983 - accuracy: 0.9229 - val_loss: 0.8855 - val_accuracy: 0.7895
# Epoch 35/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.2343 - accuracy: 0.9422 - val_loss: 0.9450 - val_accuracy: 0.7895
# Epoch 36/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.2959 - accuracy: 0.9461 - val_loss: 0.8595 - val_accuracy: 0.8289
# Epoch 37/60
# 75/75 [==============================] - 9s 117ms/step - loss: 0.2863 - accuracy: 0.9317 - val_loss: 0.8734 - val_accuracy: 0.8289
# Epoch 38/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.2140 - accuracy: 0.9281 - val_loss: 0.8984 - val_accuracy: 0.7895
# Epoch 39/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.3554 - accuracy: 0.9058 - val_loss: 0.8736 - val_accuracy: 0.8289
# Epoch 40/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.2383 - accuracy: 0.9295 - val_loss: 0.9036 - val_accuracy: 0.8289
# Epoch 41/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.2297 - accuracy: 0.9279 - val_loss: 0.9870 - val_accuracy: 0.8289
# Epoch 42/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.1891 - accuracy: 0.9638 - val_loss: 0.8236 - val_accuracy: 0.8553
# Epoch 43/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.1958 - accuracy: 0.9398 - val_loss: 0.8793 - val_accuracy: 0.8158
# Epoch 44/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.2250 - accuracy: 0.9459 - val_loss: 0.9039 - val_accuracy: 0.8158
# Epoch 45/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.2055 - accuracy: 0.9412 - val_loss: 0.9929 - val_accuracy: 0.8026
# Epoch 46/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.3231 - accuracy: 0.8870 - val_loss: 0.9187 - val_accuracy: 0.8158
# Epoch 47/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.1321 - accuracy: 0.9448 - val_loss: 0.9295 - val_accuracy: 0.8289
# Epoch 48/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.2155 - accuracy: 0.9227 - val_loss: 0.8823 - val_accuracy: 0.8026
# Epoch 49/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.1056 - accuracy: 0.9736 - val_loss: 0.9305 - val_accuracy: 0.8158
# Epoch 50/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.1417 - accuracy: 0.9668 - val_loss: 0.9507 - val_accuracy: 0.8289
# Epoch 51/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.1628 - accuracy: 0.9568 - val_loss: 0.9516 - val_accuracy: 0.8158
# Epoch 52/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.1453 - accuracy: 0.9534 - val_loss: 0.9676 - val_accuracy: 0.8421
# Epoch 53/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.1339 - accuracy: 0.9643 - val_loss: 0.9799 - val_accuracy: 0.8289
# Epoch 54/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.1457 - accuracy: 0.9541 - val_loss: 1.0310 - val_accuracy: 0.8421
# Epoch 55/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.1261 - accuracy: 0.9643 - val_loss: 1.0179 - val_accuracy: 0.8553
# Epoch 56/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.2567 - accuracy: 0.9281 - val_loss: 1.0908 - val_accuracy: 0.8026
# Epoch 57/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.1774 - accuracy: 0.9334 - val_loss: 1.0567 - val_accuracy: 0.8289
# Epoch 58/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.1550 - accuracy: 0.9505 - val_loss: 1.0516 - val_accuracy: 0.8289
# Epoch 59/60
# 75/75 [==============================] - 9s 114ms/step - loss: 0.1469 - accuracy: 0.9374 - val_loss: 1.0547 - val_accuracy: 0.8158
# Epoch 60/60
# 75/75 [==============================] - 9s 115ms/step - loss: 0.1163 - accuracy: 0.9624 - val_loss: 1.0763 - val_accuracy: 0.8289

# %%
# Hyper-parameter tuning CNN model using Random Search CV
base_model = Xception(include_top=False,weights='imagenet',input_shape=(IMAGE_SIZE,IMAGE_SIZE,3))
def build(hp):

  add_model = Sequential()
  add_model.add(Flatten(input_shape=base_model.output_shape[1:]))
  add_model.add(Dropout(rate=hp.Float(
                'dropout_1',
                min_value=0.4,
                max_value=0.55,
                default=0.4,
                step=0.05,)))
  add_model.add(Dense(
          units=hp.Int(
                    'units',
                    min_value=128,
                    max_value=512,
                    step=32,
                    default=128),activation='relu'))
  add_model.add(Dropout(rate=hp.Float('dropout_2',
                min_value=0.4,
                max_value=0.55,
                default=0.4,
                step=0.05)))
  add_model.add(Dense(8,activation='softmax'))
  model = Model(inputs=base_model.input,outputs = add_model(base_model.output))
  model.compile(loss='categorical_crossentropy', optimizer=
                    optimizers.Adam(
                    hp.Float(
                    'learning_rate',
                    min_value=1e-5,
                    max_value=1e-2,
                    sampling='LOG',
                    default=1e-3
                )
            ), metrics=['accuracy'])
  return model
 
SEED=1
tuner = RandomSearch(
    build,
    objective='val_accuracy',
    seed=SEED,
    max_trials=10,
    executions_per_trial=1,
    directory='random_search',
    project_name='CNN'
)
train_datagen = ImageDataGenerator(
        rotation_range=30, 
        width_shift_range=0.1, 
        height_shift_range=0.1,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
train_datagen.fit(x_train)
history = tuner.search(train_datagen.flow(x_train, y_train,batch_size=4), epochs=90, validation_data = (x_valid,y_valid), steps_per_epoch=len(x_train)//4,verbose=1)
# Out:
# Trial 10 Complete [00h 13m 01s]
# val_accuracy: 0.4868420958518982
#
# Best val_accuracy So Far: 0.8684210777282715
# Total elapsed time: 02h 06m 28s
# INFO:tensorflow:Oracle triggered exit

# %%
# Summary of the Hyper-Parameter Tuning Results
tuner.results_summary()
# Out:
# Results summary
# Results in random_search/CNN
# Showing 10 best trials
# Objective(name='val_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# dropout_1: 0.4
# units: 480
# dropout_2: 0.45
# learning_rate: 5.1067461389326326e-05
# Score: 0.8684210777282715
# Trial summary
# Hyperparameters:
# dropout_1: 0.5
# units: 448
# dropout_2: 0.45
# learning_rate: 4.7875969115132644e-05
# Score: 0.8552631735801697
# Trial summary
# Hyperparameters:
# dropout_1: 0.45
# units: 352
# dropout_2: 0.45
# learning_rate: 0.00026528459787494564
# Score: 0.8552631735801697
# Trial summary
# Hyperparameters:
# dropout_1: 0.45
# units: 160
# dropout_2: 0.55
# learning_rate: 0.0001214977750028307
# Score: 0.8421052694320679
# Trial summary
# Hyperparameters:
# dropout_1: 0.5
# units: 384
# dropout_2: 0.45
# learning_rate: 0.0002375856074002887
# Score: 0.4868420958518982
# Trial summary
# Hyperparameters:
# dropout_1: 0.5
# units: 320
# dropout_2: 0.5
# learning_rate: 9.685043186070346e-05
# Score: 0.3552631437778473
# Trial summary
# Hyperparameters:
# dropout_1: 0.4
# units: 480
# dropout_2: 0.55
# learning_rate: 0.001370973194523569
# Score: 0.30263158679008484
# Trial summary
# Hyperparameters:
# dropout_1: 0.5
# units: 320
# dropout_2: 0.4
# learning_rate: 1.707125114555644e-05
# Score: 0.30263158679008484
# Trial summary
# Hyperparameters:
# dropout_1: 0.45
# units: 416
# dropout_2: 0.5
# learning_rate: 2.1820842293838312e-05
# Score: 0.2763157784938812
# Trial summary
# Hyperparameters:
# dropout_1: 0.5
# units: 192
# dropout_2: 0.5
# learning_rate: 0.005210975466852393
# Score: 0.22368420660495758

# %%
#Extracting the best CNN model
best_model = tuner.get_best_models(num_models=1)[0] # Best_val accuracy is 86.84%

# %%
# loss curves of trained Model
plt.figure(figsize=[10, 6])
plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)
plt.legend(['Training loss', 'Validation loss'], fontsize=18)
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.title('Loss Curves', fontsize=16)
plt.show()

# Accuracy curves of the trained Model
plt.figure(figsize=[15, 10])
plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Accuracy Curves', fontsize=16)
plt.show()

# %% [markdown]
# Preparing Testing Data

# %%
## Calling the read_img function
test_img = []
for img_name in tqdm(test_csv['Image'].values):
  test_img.append(read_img(TEST_PATH+img_name))
# Out:
# 100%|██████████| 156/156 [01:32<00:00,  1.68it/s]

# %%
# Converting it into float arrays and normalizing it
X_test = np.array(test_img,np.float32)/255
mean_img = np.mean(X_test,axis=0)
std_img = np.std(X_test,axis=0)
X_test = (X_test-mean_img) / std_img

# %%
#Predictions on testing data
#predictions = model.predict(X_test) # W/o.r.t Hyper-parameter modelling
predictions = best_model.predict(X_test) # W.r.t Hyper-parameter modelling

# %%
#Unrolling Predictions
predictions = np.argmax(predictions,axis=1)
rev_y = {v:k for k,v in label_numeric.items()}
pred_labels = [rev_y[k] for k in predictions]

# %%
# Final Predictions
output = pd.DataFrame({"Image":test_csv.Image,"target":pred_labels})
filename = "Identify_dance_forms.csv"
output.to_csv(filename,index=False)
output.head()
# Out:
#      Image         target
# 0  508.jpg      kuchipudi
# 1  246.jpg      kuchipudi
# 2  473.jpg         odissi
# 3  485.jpg         odissi
# 4  128.jpg  bharatanatyam
